# %%
import model_evaluation
model_evaluation.main()
# Out:
# /home/U2017042/project/data/trains_data.py:19: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   return cols_data.as_matrix()
# INFO:tensorflow:Restoring parameters from ./data/files/sessions/001040.ckpt
# INFO:tensorflow:Restoring parameters from ./data/files/sessions/001040.ckpt
# 1 1040 CJ 0.027170561 9425392.75 9320377.0 0
# INFO:tensorflow:Restoring parameters from ./data/files/sessions/000640.ckpt
# INFO:tensorflow:Restoring parameters from ./data/files/sessions/000640.ckpt
# 2 640 동아쏘시오홀딩스 0.030872876 10242197.5 10824738.6 0
# INFO:tensorflow:Restoring parameters from ./data/files/sessions/000400.ckpt
# INFO:tensorflow:Restoring parameters from ./data/files/sessions/000400.ckpt
# 3 400 롯데손해보험 0.0064924904 9564365.820249999 9564365.820249999 0
# INFO:tensorflow:Restoring parameters from ./data/files/sessions/000810.ckpt
# INFO:tensorflow:Restoring parameters from ./data/files/sessions/000810.ckpt
# ...
